# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102018 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f5d1451cb00>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f5d1451c748>)

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a1832b88a211> in <module>()
#       3 # different experiments you run.
#       4
# ----> 5 from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer
#       6 from mlp.errors import CrossEntropySoftmaxError
#       7 from mlp.models import MultipleLayerModel
#
# ModuleNotFoundError: No module named 'mlp'

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
from collections import OrderedDict

# %% [markdown]
# ## Baseline

# %% [markdown]
# ### find learning rate

# %%
num_hidden_layers = [2, 3, 4, 5]
learning_rates = [0.1, 0.05, 0.01]
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100
error = CrossEntropySoftmaxError()
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)

models = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []

row = 0
for num in num_hidden_layers:
    row += 1
    col = 0
    for learning_rate in learning_rates:
        col += 1
        layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init), ReluLayer()]
        for i in range(num-1):
            layers.append(AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init))
            layers.append(ReluLayer())
        layers.append(AffineLayer(hidden_dim, output_dim, weights_init, biases_init))
        
        model = MultipleLayerModel(layers)
        
        learning_rule = GradientDescentLearningRule(learning_rate)
        stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
        plt.show()
        
        models[(num, learning_rate)] = model
        
        final_train_errors.append(stats[-1, keys['error(train)']])
        final_valid_errors.append(stats[-1, keys['error(valid)']])
        final_train_accs.append(stats[-1, keys['acc(train)']])
        final_valid_accs.append(stats[-1, keys['acc(valid)']])
        
shape = (row, col)
final_train_errors = np.reshape(final_train_errors, shape)
final_valid_errors = np.reshape(final_valid_errors, shape)
final_train_accs = np.reshape(final_train_accs, shape)
final_valid_accs = np.reshape(final_valid_accs, shape)
# Out:
# ...
# Epoch 1: 2.3s to complete
#     error(train)=1.12e+00, acc(train)=6.74e-01, error(valid)=1.12e+00, acc(valid)=6.66e-01
# ...
# Epoch 2: 2.0s to complete
#     error(train)=8.24e-01, acc(train)=7.46e-01, error(valid)=8.38e-01, acc(valid)=7.39e-01
# ...
# Epoch 3: 2.1s to complete
#     error(train)=6.95e-01, acc(train)=7.79e-01, error(valid)=7.14e-01, acc(valid)=7.75e-01
# ...
# Epoch 4: 2.0s to complete
#     error(train)=6.08e-01, acc(train)=8.04e-01, error(valid)=6.33e-01, acc(valid)=7.98e-01
# ...
# Epoch 5: 1.9s to complete
#     error(train)=5.56e-01, acc(train)=8.19e-01, error(valid)=5.90e-01, acc(valid)=8.07e-01
# ...
# Epoch 6: 1.9s to complete
#     error(train)=5.17e-01, acc(train)=8.31e-01, error(valid)=5.58e-01, acc(valid)=8.21e-01
# ...
# Epoch 7: 1.9s to complete
#     error(train)=5.02e-01, acc(train)=8.35e-01, error(valid)=5.49e-01, acc(valid)=8.22e-01
# ...
# Epoch 8: 2.0s to complete
#     error(train)=4.63e-01, acc(train)=8.45e-01, error(valid)=5.25e-01, acc(valid)=8.26e-01
# ...
# Epoch 9: 1.9s to complete
# ...

# %%
final_train_accs

# %%
print('| num_hidden_layers | learning_rate | final train error | final valid error | final train acc | final valid acc |')
print('|-------------------|---------------|-------------------|-------------------|-----------------|-----------------|')
for i,num in enumerate(num_hidden_layers):
    for j,learning_rate in enumerate(learning_rates):
        print('| {0:d}                 | {1:2e}  | {2:3e}      | {3:3e})     | {4:3f}        | {5:3f}        |'
              .format(num, learning_rate,
                     final_train_errors[i, j], final_valid_errors[i, j],
                     final_train_accs[i, j], final_valid_accs[i, j]))
# Out:
# | num_hidden_layers | learning_rate | final train error | final valid error | final train acc | final valid acc |
# |-------------------|---------------|-------------------|-------------------|-----------------|-----------------|
# | 2                 | 1.000000e-01  | 1.712570e-01      | 8.384739e-01)     | 0.929990        | 0.815380        |
# | 2                 | 5.000000e-02  | 2.107561e-01      | 6.128885e-01)     | 0.920460        | 0.830127        |
# | 2                 | 1.000000e-02  | 4.159580e-01      | 5.048069e-01)     | 0.860940        | 0.835570        |
# | 3                 | 1.000000e-01  | 1.670965e-01      | 9.632751e-01)     | 0.932720        | 0.822848        |
# | 3                 | 5.000000e-02  | 1.611884e-01      | 7.311667e-01)     | 0.936270        | 0.829937        |
# | 3                 | 1.000000e-02  | 3.529269e-01      | 4.848696e-01)     | 0.876440        | 0.840190        |
# ...

# %% [markdown]
# Num hidden layers:2, learning_rate:0.01, num_epochs=100;
#
# Num hidden layers:3, learning_rate:0.01, num_epochs=100;
#
# Num hidden layers:4, learning_rate:0.01, num_epochs=100;
#
# Num hidden layers:5, learning_rate:0.05, num_epochs=30;

# %% [markdown]
# ### compare the accuracy on test data

# %%
def evaluation_acc(dataset, model):
    for inputs, targets in dataset:
        activations = model.fprop(inputs, evaluation=True)
        predictions = activations[-1]
        acc = (predictions.argmax(-1) == targets.argmax(-1)).mean()
    return acc

# %%
indices = [2, 5, 8, 10]

# %%
test_data = EMNISTDataProvider('test', batch_size=15800, rng=rng)
test_accs = []

indices = [2, 5, 8, 10]
for idx in indices:
    model = list(models.values())[idx]
    acc = evaluation_acc(test_data, model)
    test_accs.append(acc)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x11fb7cef0>)

# %%
print('| num_hidden_layers | final test acc |')
print('|-------------------|----------------|')
for i,num in enumerate(num_hidden_layers):
    print('| {0:d}                 | {1:3f}       |'
            .format(num, test_accs[i]))
# Out:
# | num_hidden_layers | final test acc |
# |-------------------|----------------|
# | 2                 | 0.826519       |
# | 3                 | 0.828608       |
# | 4                 | 0.819494       |
# | 5                 | 0.819937       |

# %% [markdown]
# ## Adam and RMSProp

# %%
from imp import reload
from mlp import learning_rules
reload(learning_rules)
from mlp.learning_rules import AdamLearningRule, RMSPropLearningRule, GradientDescentLearningRule, AdaGradLearningRule

# %%
learning_rules = ['Adam', 'RMSProp' 'SGD']
num_epochs = 100
input_dim, output_dim, hidden_dim = 784, 47, 100
error = CrossEntropySoftmaxError()
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)

models = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []

for learning

# %%
num_epochs = 100
input_dim, output_dim, hidden_dim = 784, 47, 100
error = CrossEntropySoftmaxError()
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)
stats_interval = 1

# %% [markdown]
# ### Adam

# %%
num_epochs = 100
layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

adam_model = MultipleLayerModel(layers)
adam_learning_rule = AdamLearningRule(learning_rate=0.0001, beta_1=0.85, beta_2=0.95, epsilon=1e-8)

adam_stats, adam_keys, adam_run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
            adam_model, error, adam_learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
plt.show()
# Out:
# ...
# Epoch 1: 1.9s to complete
#     error(train)=2.05e+00, acc(train)=4.58e-01, error(valid)=2.05e+00, acc(valid)=4.53e-01
# ...
# Epoch 2: 2.0s to complete
#     error(train)=1.60e+00, acc(train)=5.59e-01, error(valid)=1.60e+00, acc(valid)=5.55e-01
# ...
# Epoch 3: 2.0s to complete
#     error(train)=1.40e+00, acc(train)=6.11e-01, error(valid)=1.40e+00, acc(valid)=6.07e-01
# ...
# Epoch 4: 1.9s to complete
#     error(train)=1.27e+00, acc(train)=6.42e-01, error(valid)=1.27e+00, acc(valid)=6.40e-01
# ...
# Epoch 5: 2.3s to complete
#     error(train)=1.17e+00, acc(train)=6.67e-01, error(valid)=1.18e+00, acc(valid)=6.65e-01
# ...
# Epoch 6: 2.0s to complete
#     error(train)=1.08e+00, acc(train)=6.88e-01, error(valid)=1.09e+00, acc(valid)=6.88e-01
# ...
# Epoch 7: 2.1s to complete
#     error(train)=1.02e+00, acc(train)=7.05e-01, error(valid)=1.02e+00, acc(valid)=7.02e-01
# ...
# Epoch 8: 2.1s to complete
#     error(train)=9.62e-01, acc(train)=7.18e-01, error(valid)=9.71e-01, acc(valid)=7.17e-01
# ...
# Epoch 9: 2.1s to complete
# ...

# %% [markdown]
# ### RMSProp

# %%
num_epochs = 100
layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

rmsprop_model = MultipleLayerModel(layers)
rmsprop_learning_rule = RMSPropLearningRule(learning_rate=0.0001, beta=0.9, epsilon=1e-8)

rmsprop_stats, rmsprop_keys, rmsprop_run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
            rmsprop_model, error, rmsprop_learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
plt.show()
# Out:
# ...
# Epoch 1: 1.6s to complete
#     error(train)=2.07e+00, acc(train)=4.55e-01, error(valid)=2.06e+00, acc(valid)=4.56e-01
# ...
# Epoch 2: 1.8s to complete
#     error(train)=1.60e+00, acc(train)=5.59e-01, error(valid)=1.60e+00, acc(valid)=5.58e-01
# ...
# Epoch 3: 1.6s to complete
#     error(train)=1.39e+00, acc(train)=6.09e-01, error(valid)=1.40e+00, acc(valid)=6.07e-01
# ...
# Epoch 4: 1.6s to complete
#     error(train)=1.26e+00, acc(train)=6.43e-01, error(valid)=1.26e+00, acc(valid)=6.44e-01
# ...
# Epoch 5: 1.6s to complete
#     error(train)=1.16e+00, acc(train)=6.66e-01, error(valid)=1.17e+00, acc(valid)=6.65e-01
# ...
# Epoch 6: 1.6s to complete
#     error(train)=1.08e+00, acc(train)=6.86e-01, error(valid)=1.09e+00, acc(valid)=6.84e-01
# ...
# Epoch 7: 1.6s to complete
#     error(train)=1.02e+00, acc(train)=7.04e-01, error(valid)=1.03e+00, acc(valid)=7.04e-01
# ...
# Epoch 8: 1.6s to complete
#     error(train)=9.63e-01, acc(train)=7.18e-01, error(valid)=9.71e-01, acc(valid)=7.17e-01
# ...
# Epoch 9: 1.7s to complete
# ...

# %% [markdown]
# ### SGD

# %%
num_epochs = 100
layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
          ReluLayer(),
          AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

sgd_model = MultipleLayerModel(layers)
sgd_learning_rule = GradientDescentLearningRule(0.01)

sgd_stats, sgd_keys, sgd_run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
            sgd_model, error, sgd_learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
plt.show()
# Out:
# ...
# Epoch 1: 1.3s to complete
#     error(train)=3.84e+00, acc(train)=6.95e-02, error(valid)=3.84e+00, acc(valid)=6.91e-02
# ...
# Epoch 2: 1.2s to complete
#     error(train)=3.73e+00, acc(train)=5.57e-02, error(valid)=3.73e+00, acc(valid)=5.76e-02
# ...
# Epoch 3: 1.3s to complete
#     error(train)=3.00e+00, acc(train)=2.22e-01, error(valid)=2.99e+00, acc(valid)=2.18e-01
# ...
# Epoch 4: 1.2s to complete
#     error(train)=2.04e+00, acc(train)=4.42e-01, error(valid)=2.03e+00, acc(valid)=4.36e-01
# ...
# Epoch 5: 1.2s to complete
#     error(train)=1.78e+00, acc(train)=5.13e-01, error(valid)=1.77e+00, acc(valid)=5.07e-01
# ...
# Epoch 6: 1.3s to complete
#     error(train)=1.61e+00, acc(train)=5.52e-01, error(valid)=1.61e+00, acc(valid)=5.44e-01
# ...
# Epoch 7: 1.2s to complete
#     error(train)=1.46e+00, acc(train)=5.90e-01, error(valid)=1.46e+00, acc(valid)=5.85e-01
# ...
# Epoch 8: 1.3s to complete
#     error(train)=1.34e+00, acc(train)=6.20e-01, error(valid)=1.35e+00, acc(valid)=6.17e-01
# ...
# Epoch 9: 1.2s to complete
# ...

# %%
stats = OrderedDict()
stats[AdamLearningRule(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)] = adam_stats
stats[RMSPropLearningRule(learning_rate=0.0001, beta=0.8, epsilon=1e-8)] = rmsprop_stats
stats[GradientDescentLearningRule(0.01)] = sgd_stats

learning_rules = [AdamLearningRule(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8),
                  RMSPropLearningRule(learning_rate=0.0001, beta=0.8, epsilon=1e-8),
                  GradientDescentLearningRule(0.01)]

# %%
# Plot the change in the validation and training set error over training.
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig.add_subplot(111)
ax_1.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 0], label='Adam', c='r')
ax_1.plot(np.arange(1, rmsprop_stats.shape[0]) * stats_interval, rmsprop_stats[1:, 0], label='RMSProp', c='b')
ax_1.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 0], label='SGD', c='g')
ax_1.legend(loc=0)
ax_1.set_ylabel('Error')
ax_1.set_xlabel('Epoch Number')
plt.show()
# Out:
# /usr/local/miniconda3/envs/dl/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# Plot the training error
plt.figure(figsize=(8,8))
plt.plot(np.arange(1, rmsprop_stats.shape[0]) * stats_interval, rmsprop_stats[1:, 0], label='RMSProp', c='b')
plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 0], label='Adam', c='r')
plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 0], label='SGD', c='g')
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Training Error Curves')
plt.savefig('./plots/training_error_curves.png', dpi=1000)
plt.savefig('./plots/training_error_curves.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the validation error
plt.close()
plt.figure(figsize=(8,8))
plt.plot(np.arange(1, rmsprop_stats.shape[0]) * stats_interval, rmsprop_stats[1:, 2], label='RMSProp', c='b')
plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 2], label='Adam', c='r')
plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 2], label='SGD', c='g')
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Error Curves')
plt.savefig('./plots/valid_error_curves.png', dpi=1000)
plt.savefig('./plots/valid_error_curves.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training acc
plt.close()
plt.figure(figsize=(8,8))
plt.plot(np.arange(1, rmsprop_stats.shape[0]) * stats_interval, rmsprop_stats[1:, 1], label='RMSProp', c='b')
plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 1], label='Adam', c='r')
plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 1], label='SGD', c='g')
plt.legend(loc=0)
plt.ylabel('Accuracy')
plt.xlabel('Epoch Number')
plt.title('Training Accuracy Curves')
plt.savefig('./plots/training_acc_curves.png', dpi=1000)
plt.savefig('./plots/training_acc_curves.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the validation acc
plt.close()
plt.figure(figsize=(8,8))
plt.plot(np.arange(1, rmsprop_stats.shape[0]) * stats_interval, rmsprop_stats[1:, -1], label='RMSProp', c='b')
plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, -1], label='Adam', c='r')
plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, -1], label='SGD', c='g')
plt.legend(loc=0)
plt.ylabel('Accuracy')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy Curves')
plt.savefig('./plots/valid_acc_curves.png', dpi=1000)
plt.savefig('./plots/valid_acc_curves.eps', format='eps', dpi=1000)
plt.show()

# %%
test_data = EMNISTDataProvider('test', batch_size=15800, rng=rng)
test_accs = []
adam_acc = evaluation_acc(test_data, adam_model)
test_accs.append(adam_acc)
rmsprop_acc = evaluation_acc(test_data, rmsprop_model)
test_accs.append(rmsprop_acc)
sgd_acc = evaluation_acc(test_data, sgd_model)
test_accs.append(sgd_acc)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f5ce74e7f28>)

# %%
print('| learning_rules | final test acc |')
print('|----------------|----------------|')
print('| Adam           | {0:3f}       |'.format(test_accs[0]))
print('| RMSProp        | {0:3f}       |'.format(test_accs[1]))
print('| SGD            | {0:3f}       |'.format(test_accs[2]))
# Out:
# | learning_rules | final test acc |
# |----------------|----------------|
# | Adam           | 0.830633       |
# | RMSProp        | 0.830570       |
# | SGD            | 0.829873       |

# %% [markdown]
# ## Cosine Annealing Learning Rate Scheduler

# %%
from imp import reload
from mlp import learning_rules
from mlp import optimisers
from mlp.schedulers import CosineAnnealingWithWarmRestarts
reload(optimisers)
reload(learning_rules)
from mlp.learning_rules import AdamLearningRule, RMSPropLearningRule, GradientDescentLearningRule, AdaGradLearningRule,AdamLearningRuleWithWeightDecay
from mlp.optimisers import Optimiser

# %%
def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, scheduler, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval, scheduler=scheduler)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser

# %%
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100
error = CrossEntropySoftmaxError()
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)

# %%
num_epochs = 100
sgd_schedulers = [
    None,
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.005, 
                                    max_learning_rate=0.015,
                                    total_iters_per_period=100.,
                                    max_learning_rate_discount_factor=0.8,
                                    period_iteration_expansion_factor=1.0),
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.005, 
                                    max_learning_rate=0.015,
                                    total_iters_per_period=25.0,
                                    max_learning_rate_discount_factor=0.8,
                                    period_iteration_expansion_factor=3.0)]
sgd_models = OrderedDict()
sgd_lrs = OrderedDict()
stats = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []


for scheduler in sgd_schedulers:
    layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

    sgd_model = MultipleLayerModel(layers)
    sgd_learning_rule = GradientDescentLearningRule(0.01)

    sgd_stats, sgd_keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
            sgd_model, error, sgd_learning_rule, train_data, valid_data, num_epochs, scheduler, stats_interval, notebook=True)
    plt.show()
    
    sgd_models[scheduler] = sgd_model
    sgd_lrs[scheduler] = optimiser.learning_rate_array
    stats[scheduler] = sgd_stats
    final_train_errors.append(sgd_stats[-1, 0])
    final_valid_errors.append(sgd_stats[-1, 2])
    final_train_accs.append(sgd_stats[-1, 1])
    final_valid_accs.append(sgd_stats[-1, -1])
    
    print('    final error(train) = {0:.2e}'.format(sgd_stats[-1, 0]))
    print('    final error(valid) = {0:.2e}'.format(sgd_stats[-1, 2]))
    print('    final acc(train)   = {0:.2e}'.format(sgd_stats[-1, 1]))
    print('    final acc(valid)   = {0:.2e}'.format(sgd_stats[-1, -1]))
    print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))
# Out:
# ...
# Epoch 1: 1.3s to complete
#     error(train)=3.84e+00, acc(train)=6.18e-02, error(valid)=3.84e+00, acc(valid)=5.97e-02
# ...
# Epoch 2: 1.2s to complete
#     error(train)=3.77e+00, acc(train)=9.72e-02, error(valid)=3.77e+00, acc(valid)=9.21e-02
# ...
# Epoch 3: 1.3s to complete
#     error(train)=3.19e+00, acc(train)=1.81e-01, error(valid)=3.18e+00, acc(valid)=1.77e-01
# ...
# Epoch 4: 1.2s to complete
#     error(train)=2.24e+00, acc(train)=4.00e-01, error(valid)=2.23e+00, acc(valid)=4.02e-01
# ...
# Epoch 5: 1.2s to complete
#     error(train)=1.71e+00, acc(train)=5.28e-01, error(valid)=1.71e+00, acc(valid)=5.25e-01
# ...
# Epoch 6: 1.2s to complete
#     error(train)=1.48e+00, acc(train)=5.84e-01, error(valid)=1.49e+00, acc(valid)=5.75e-01
# ...
# Epoch 7: 1.2s to complete
#     error(train)=1.36e+00, acc(train)=6.14e-01, error(valid)=1.36e+00, acc(valid)=6.10e-01
# ...
# Epoch 8: 1.2s to complete
#     error(train)=1.26e+00, acc(train)=6.39e-01, error(valid)=1.27e+00, acc(valid)=6.35e-01
# ...
# Epoch 9: 1.2s to complete
# ...

# %%
num_epochs = 100
sgd_schedulers = [
    None,
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.00005, 
                                    max_learning_rate=0.0002,
                                    total_iters_per_period=100.,
                                    max_learning_rate_discount_factor=0.8,
                                    period_iteration_expansion_factor=1.0),
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.00005, 
                                    max_learning_rate=0.0002,
                                    total_iters_per_period=25.0,
                                    max_learning_rate_discount_factor=0.8,
                                    period_iteration_expansion_factor=3.0)]
adam_models = OrderedDict()
adam_lrs = OrderedDict()
A_stats = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []


for scheduler in sgd_schedulers:
    layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

    adam_model = MultipleLayerModel(layers)
    adam_learning_rule = GradientDescentLearningRule(0.01)

    adam_stats, adam_keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
            adam_model, error, adam_learning_rule, train_data, valid_data, num_epochs, scheduler, stats_interval, notebook=True)
    plt.show()
    
    adam_models[scheduler] = adam_model
    adam_lrs[scheduler] = optimiser.learning_rate_array
    A_stats[scheduler] = adam_stats
    final_train_errors.append(adam_stats[-1, 0])
    final_valid_errors.append(adam_stats[-1, 2])
    final_train_accs.append(adam_stats[-1, 1])
    final_valid_accs.append(adam_stats[-1, -1])
    
    print('    final error(train) = {0:.2e}'.format(adam_stats[-1, 0]))
    print('    final error(valid) = {0:.2e}'.format(adam_stats[-1, 2]))
    print('    final acc(train)   = {0:.2e}'.format(adam_stats[-1, 1]))
    print('    final acc(valid)   = {0:.2e}'.format(adam_stats[-1, -1]))
    print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

# %% [markdown]
# Plot the histogram of the weights

# %%
adam_lrs
# Out:
# OrderedDict([(None,
#               [0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
#                0.0001,
# ...

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['', ' cosine annealing with no restarts', ' cosine annealing with restarts']
for sgd_lr, k in zip(list(sgd_lrs.values()), labels):
    plt.plot(np.arange(len(sgd_lr)), sgd_lr, label='SGD' + k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Learning Rate')
plt.xlabel('Epoch Number')
plt.title('SGD')
plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['', ' cosine annealing with no restarts', ' cosine annealing with restarts']
for adam_lr, k in zip(list(adam_lrs.values()), labels):
    plt.plot(np.arange(len(adam_lr)), adam_lr, label='Adam' + k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Learning Rate')
plt.xlabel('Epoch Number')
plt.title('Adam')
plt.savefig('./plots/4_3_adam_lr.png', dpi=1000)
plt.savefig('./plots/4_3_adam_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training error
plt.close()
plt.figure(figsize=(8,8))
labels = ['', ' cosine annealing with no restarts', ' cosine annealing with restarts']
for sgd_stats, adam_stats, k in zip(list(stats.values()),list(A_stats.values()), labels):
    plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 0], label='SGD' + k, linewidth=2)
    plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 0], label='Adam' + k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Training Errors')
plt.savefig('./plots/4_3_training_error.png', dpi=1000)
plt.savefig('./plots/4_3_training_error.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the validation error
plt.close()
plt.figure(figsize=(8,8))
labels = ['', ' cosine annealing with no restarts', ' cosine annealing with restarts']
for sgd_stats, adam_stats, k in zip(list(stats.values()),list(A_stats.values()), labels):
    plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 2], label='SGD' + k, linewidth=2)
    plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 2], label='Adam' + k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Errors')
plt.savefig('./plots/4_3_valid_error.png', dpi=1000)
plt.savefig('./plots/4_3_valid_error.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['', ' cosine annealing with no restarts', ' cosine annealing with restarts']
for sgd_stats, adam_stats, k in zip(list(stats.values()),list(A_stats.values()), labels):
    plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, 1], label='SGD' + k, linewidth=2)
    plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, 1], label='Adam' + k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Training Accuracy')
plt.savefig('./plots/4_3_training_acc.png', dpi=1000)
plt.savefig('./plots/4_3_training_acc.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['', ' cosine annealing with no restarts', ' cosine annealing with restarts']
for sgd_stats, adam_stats, k in zip(list(stats.values()),list(A_stats.values()), labels):
    plt.plot(np.arange(1, sgd_stats.shape[0]) * stats_interval, sgd_stats[1:, -1], label='SGD' + k, linewidth=2)
    plt.plot(np.arange(1, adam_stats.shape[0]) * stats_interval, adam_stats[1:, -1], label='Adam' + k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
plt.savefig('./plots/4_3_valid_acc.png', dpi=1000)
plt.savefig('./plots/4_3_valid_acc.eps', format='eps', dpi=1000)
plt.show()

# %%
adam_models
# Out:
# OrderedDict([(None, MultiLayerModel(
#                   AffineLayer(input_dim=784, output_dim=100)
#                   ReluLayer
#                   AffineLayer(input_dim=100, output_dim=100)
#                   ReluLayer
#                   AffineLayer(input_dim=100, output_dim=100)
#                   ReluLayer
#                   AffineLayer(input_dim=100, output_dim=47)
#               )),
#              (<mlp.schedulers.CosineAnnealingWithWarmRestarts at 0x7f5ce577a358>,
#               MultiLayerModel(
#                   AffineLayer(input_dim=784, output_dim=100)
#                   ReluLayer
#                   AffineLayer(input_dim=100, output_dim=100)
#                   ReluLayer
#                   AffineLayer(input_dim=100, output_dim=100)
#                   ReluLayer
#                   AffineLayer(input_dim=100, output_dim=47)
#               )),
#              (<mlp.schedulers.CosineAnnealingWithWarmRestarts at 0x7f5ce577a390>,
#               MultiLayerModel(
# ...

# %%
test_data = EMNISTDataProvider('test', batch_size=15800, rng=rng)
test_accs = []
for sgd_model, adam_model in zip(list(sgd_models.values()), list(adam_models.values())):
    sgd_acc = evaluation_acc(test_data, sgd_model)
    test_accs.append(sgd_acc)
    adam_acc = evaluation_acc(test_data, adam_model)
    test_accs.append(adam_acc)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f5ce2d34cc0>)

# %%
print('|     methods     | final valid error| final valid acc | final test acc  |')
print('|---------------- |------------------|-----------------|-----------------|')
print('| SGD             | {0:3f}         | {1:3f}        | {2:3f}        |'.format(list(stats.values())[0][-1, 2], list(stats.values())[0][-1, -1], test_accs[0]))
print('| Adam            | {0:3f}         | {1:3f}        | {2:3f}        |'.format(list(A_stats.values())[0][-1, 2], list(A_stats.values())[0][-1, -1], test_accs[1]))
print('| SGD+cos         | {0:3f}         | {1:3f}        | {2:3f}        |'.format(list(stats.values())[1][-1, 2], list(stats.values())[1][-1, -1], test_accs[2]))
print('| Adam+cos        | {0:3f}         | {1:3f}        | {2:3f}        |'.format(list(A_stats.values())[1][-1, 2], list(A_stats.values())[1][-1, -1], test_accs[3]))
print('| SGD+cos+restart | {0:3f}         | {1:3f}        | {2:3f}        |'.format(list(stats.values())[1][-1, 2], list(stats.values())[2][-1, -1], test_accs[4]))
print('| Adam+cos+restart| {0:3f}         | {1:3f}        | {2:3f}        |'.format(list(A_stats.values())[1][-1, 2], list(A_stats.values())[2][-1, -1], test_accs[5]))
# Out:
# |     methods     | final valid error| final valid acc | final test acc  |
# |---------------- |------------------|-----------------|-----------------|
# | SGD             | 0.496494         | 0.839747        | 0.831013        |
# | Adam            | 0.507918         | 0.839304        | 0.826962        |
# | SGD+cos         | 0.492472         | 0.842278        | 0.831582        |
# | Adam+cos        | 0.517860         | 0.841266        | 0.828924        |
# | SGD+cos+restart | 0.492472         | 0.835633        | 0.826013        |
# | Adam+cos+restart| 0.517860         | 0.842342        | 0.832215        |

# %% [markdown]
# ## 4.4.1 Regularization vs. weight decay

# %%
from mlp.penalties import L2Penalty

# %%
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100
error = CrossEntropySoftmaxError()
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)
num_epochs = 100

# %%
penalties = [
    L2Penalty(0.1),
    L2Penalty(0.02),
    L2Penalty(0.01),
    L2Penalty(0.001),
    L2Penalty(0.0001),
    L2Penalty(0.00001),
]

num_epochs = 50

penalties_models = OrderedDict()
penalties_stats = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []

for penalty in penalties:
    layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init, penalty),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, penalty),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, penalty),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init, penalty)]

    model = MultipleLayerModel(layers)
    learning_rule = AdamLearningRule(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)

    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
            model, error, learning_rule, train_data, valid_data, num_epochs, None, stats_interval, notebook=True)
    plt.show()
    
    penalties_models[penalty] = model
    penalties_stats[penalty] = stats
    final_train_errors.append(stats[-1, 0])
    final_valid_errors.append(stats[-1, 2])
    final_train_accs.append(stats[-1, 1])
    final_valid_accs.append(stats[-1, -1])
    
    print('    final error(train) = {0:.2e}'.format(stats[-1, 0]))
    print('    final error(valid) = {0:.2e}'.format(stats[-1, 2]))
    print('    final acc(train)   = {0:.2e}'.format(stats[-1, 1]))
    print('    final acc(valid)   = {0:.2e}'.format(stats[-1, -1]))
    print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))
# Out:
# ...
# Epoch 1: 2.1s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
# ...
# Epoch 2: 1.9s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
# ...
# Epoch 3: 1.9s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
# ...
# Epoch 4: 2.0s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
# ...
# Epoch 5: 2.0s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
# ...
# Epoch 6: 1.9s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
# ...
# Epoch 7: 2.0s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
# ...
# Epoch 8: 2.4s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
# ...
# Epoch 9: 2.3s to complete
# ...

# %%
len(list(penalties_stats.values()))
# Out:
# 6

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['.1', '.02', '.01', '.001', '.0001', '.00001']
for stats, k in zip(list(penalties_stats.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, 2], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Error')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['.1', '.02', '.01', '.001', '.0001', '.00001']
for stats, k in zip(list(penalties_stats.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, -1], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Accuracy')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
print('|     methods     | final valid error| final valid acc |')
print('|---------------- |------------------|-----------------|')
for i, k in enumerate(labels):
    print('|{0:6}           | {1:3f}        |  {2:3f}        | '.format(k, list(penalties_stats.values())[i][-1, -2], list(penalties_stats.values())[i][-1, -1]))
# Out:
# |     methods     | final valid error| final valid acc |
# |---------------- |------------------|-----------------|
# |.1               | 3.850532        |  0.020127        |
# |.02              | 1.436360        |  0.601139        |
# |.01              | 0.897135        |  0.745063        |
# |.001             | 0.566725        |  0.818734        |
# |.0001            | 0.539267        |  0.825506        |
# |.00001           | 0.542086        |  0.826076        |

# %%
decay_rates = [
    0.1,
    0.02,
    0.01,
    0.001,
    0.0001,
    0.00001
]

decay_rates = np.asarray(decay_rates)

num_epochs = 50
decay_rates *= ((batch_size * 1.0 / (train_data.num_batches * num_epochs)) ** 0.5)
print(decay_rates)


decay_models = OrderedDict()
decay_stats = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []

for weight_decay in decay_rates:
    layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

    model = MultipleLayerModel(layers)
    learning_rule = AdamLearningRuleWithWeightDecay(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, weight_decay=weight_decay)

    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
            model, error, learning_rule, train_data, valid_data, num_epochs, None, stats_interval, notebook=True)
    plt.show()
    
    decay_models[weight_decay] = model
    decay_stats[weight_decay] = stats
    final_train_errors.append(stats[-1, 0])
    final_valid_errors.append(stats[-1, 2])
    final_train_accs.append(stats[-1, 1])
    final_valid_accs.append(stats[-1, -1])
    
    print('    final error(train) = {0:.2e}'.format(stats[-1, 0]))
    print('    final error(valid) = {0:.2e}'.format(stats[-1, 2]))
    print('    final acc(train)   = {0:.2e}'.format(stats[-1, 1]))
    print('    final acc(valid)   = {0:.2e}'.format(stats[-1, -1]))
    print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))
# Out:
# [4.47213595e-03 8.94427191e-04 4.47213595e-04 4.47213595e-05
#  4.47213595e-06 4.47213595e-07]
# ...
# Epoch 1: 2.0s to complete
#     error(train)=3.58e+00, acc(train)=6.79e-02, error(valid)=3.58e+00, acc(valid)=6.52e-02
# ...
# Epoch 2: 2.0s to complete
#     error(train)=3.61e+00, acc(train)=5.57e-02, error(valid)=3.61e+00, acc(valid)=5.41e-02
# ...
# Epoch 3: 2.0s to complete
#     error(train)=3.61e+00, acc(train)=5.25e-02, error(valid)=3.61e+00, acc(valid)=5.16e-02
# ...
# Epoch 4: 2.0s to complete
#     error(train)=3.59e+00, acc(train)=5.58e-02, error(valid)=3.59e+00, acc(valid)=5.37e-02
# ...
# Epoch 5: 2.0s to complete
#     error(train)=3.60e+00, acc(train)=4.91e-02, error(valid)=3.60e+00, acc(valid)=4.73e-02
# ...
# Epoch 6: 1.9s to complete
#     error(train)=3.60e+00, acc(train)=5.81e-02, error(valid)=3.60e+00, acc(valid)=5.73e-02
# ...
# Epoch 7: 2.1s to complete
#     error(train)=3.60e+00, acc(train)=5.53e-02, error(valid)=3.60e+00, acc(valid)=5.20e-02
# ...
# Epoch 8: 2.5s to complete
# ...

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['.1', '.02', '.01', '.001', '.0001', '.00001']
for stats, k in zip(list(decay_stats.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, 2], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Error')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['.1', '.02', '.01', '.001', '.0001', '.00001']
for stats, k in zip(list(decay_stats.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, -1], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Accuracy')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
print('|     methods     | final valid error| final valid acc |')
print('|---------------- |------------------|-----------------|')
for i, k in enumerate(labels):
    print('|{0:6}           | {1:3f}        |  {2:3f}        | '.format(k, list(penalties_stats.values())[i][-1, -2], list(penalties_stats.values())[i][-1, -1]))
# Out:
# |     methods     | final valid error| final valid acc |
# |---------------- |------------------|-----------------|
# |.1               | 3.850532        |  0.020127        |
# |.02              | 1.436360        |  0.601139        |
# |.01              | 0.897135        |  0.745063        |
# |.001             | 0.566725        |  0.818734        |
# |.0001            | 0.539267        |  0.825506        |
# |.00001           | 0.542086        |  0.826076        |

# %% [markdown]
# compare using optimal hyperparameters

# %%
num_epochs = 100
layers = [AffineLayer(input_dim, hidden_dim, weights_init, L2Penaltyases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

adamL2_model = MultipleLayerModel(layers)
learning_rule = AdamLearningRuleWithWeightDecay(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, weight_decay=weight_decay)
adamL2_stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
                model, error, learning_rule, train_data, valid_data, num_epochs, None, stats_interval, notebook=True)
plt.show()

final_train_errors.append(adamL2_stats[-1, 0])
final_valid_errors.append(adamL2_stats[-1, 2])
final_train_accs.append(adamL2_stats[-1, 1])
final_valid_accs.append(adamL2_stats[-1, -1])

print('    final error(train) = {0:.2e}'.format(adamL2_stats[-1, 0]))
print('    final error(valid) = {0:.2e}'.format(adamL2_stats[-1, 2]))
print('    final acc(train)   = {0:.2e}'.format(adamL2_stats[-1, 1]))
print('    final acc(valid)   = {0:.2e}'.format(adamL2_stats[-1, -1]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

# %%
num_epochs = 100
layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init, L2Penalty(0.0001)),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, L2Penalty(0.0001)),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, L2Penalty(0.0001)),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init, L2Penalty(0.0001))]

adamW_model = MultipleLayerModel(layers)
learning_rule = AdamLearningRule(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
adamW_stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
                model, error, learning_rule, train_data, valid_data, num_epochs, None, stats_interval, notebook=True)
plt.show()

final_train_errors.append(adamW_stats[-1, 0])
final_valid_errors.append(adamW_stats[-1, 2])
final_train_accs.append(adamW_stats[-1, 1])
final_valid_accs.append(adamW_stats[-1, -1])

print('    final error(train) = {0:.2e}'.format(adamW_stats[-1, 0]))
print('    final error(valid) = {0:.2e}'.format(adamW_stats[-1, 2]))
print('    final acc(train)   = {0:.2e}'.format(adamW_stats[-1, 1]))
print('    final acc(valid)   = {0:.2e}'.format(adamW_stats[-1, -1]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

# %%
test_data = EMNISTDataProvider('test', batch_size=15800, rng=rng)
test_accs = []
reg_model = list(penalties_models.values())[-2]
weight_model = list(decay_models.values())[-2]

reg_acc = evaluation_acc(test_data, reg_model)
test_accs.append(reg_acc)
weight_acc = evaluation_acc(test_data, weight_model)
test_accs.append(weight_acc)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f5ce10cda20>)

# %%
test_accs
# Out:
# [0.8126582278481013, 0.8134810126582278]

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
p_stats = list(penalties_stats.values())[-2]
w_stats = list(decay_stats.values())[-2]
plt.plot(np.arange(1, p_stats.shape[0]) * stats_interval, p_stats[1:, -1], label='L2 Regularization', linewidth=2)
plt.plot(np.arange(1, w_stats.shape[0]) * stats_interval, w_stats[1:, -1], label='Weight Decay', linewidth=2)
plt.legend(loc=0)
plt.ylabel('Accracy')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the training accuracy
plt.close()
plt.figure(figsize=(8,8))
p_stats = list(penalties_stats.values())[-2]
w_stats = list(decay_stats.values())[-2]
plt.plot(np.arange(1, p_stats.shape[0]) * stats_interval, p_stats[1:, -2], label='L2 Regularization', linewidth=2)
plt.plot(np.arange(1, w_stats.shape[0]) * stats_interval, w_stats[1:, -2], label='Weight Decay', linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Error')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# ### constant learning rate vs. cosine annealing schedule

# %% [markdown]
# constant learning rate

# %%
num_epochs = 100
weight_decay = 0.0001 * ((batch_size * 1.0 / (train_data.num_batches * num_epochs)) ** 0.5)
sches = [
    None,
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.00005, 
                                    max_learning_rate=0.00015,
                                    total_iters_per_period=100.,
                                    max_learning_rate_discount_factor=0.8,
                                    period_iteration_expansion_factor=1.0)]

sche_models = OrderedDict()
sche_stats = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []


for sche in sches:
    layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

    model = MultipleLayerModel(layers)
    learning_rule = AdamLearningRuleWithWeightDecay(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, weight_decay=weight_decay)

    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
            model, error, learning_rule, train_data, valid_data, num_epochs, sche, stats_interval, notebook=True)
    plt.show()
    
    sche_models[sche] = model
    sche_stats[sche] = stats
    final_train_errors.append(stats[-1, 0])
    final_valid_errors.append(stats[-1, 2])
    final_train_accs.append(stats[-1, 1])
    final_valid_accs.append(stats[-1, -1])
    
    print('    final error(train) = {0:.2e}'.format(stats[-1, 0]))
    print('    final error(valid) = {0:.2e}'.format(stats[-1, 2]))
    print('    final acc(train)   = {0:.2e}'.format(stats[-1, 1]))
    print('    final acc(valid)   = {0:.2e}'.format(stats[-1, -1]))
    print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))
# Out:
# ...
# Epoch 1: 2.1s to complete
#     error(train)=1.78e+00, acc(train)=5.20e-01, error(valid)=1.78e+00, acc(valid)=5.24e-01
# ...
# Epoch 2: 2.0s to complete
#     error(train)=1.47e+00, acc(train)=5.88e-01, error(valid)=1.47e+00, acc(valid)=5.89e-01
# ...
# Epoch 3: 1.9s to complete
#     error(train)=1.32e+00, acc(train)=6.26e-01, error(valid)=1.32e+00, acc(valid)=6.26e-01
# ...
# Epoch 4: 2.0s to complete
#     error(train)=1.21e+00, acc(train)=6.53e-01, error(valid)=1.22e+00, acc(valid)=6.51e-01
# ...
# Epoch 5: 2.0s to complete
#     error(train)=1.13e+00, acc(train)=6.75e-01, error(valid)=1.14e+00, acc(valid)=6.73e-01
# ...
# Epoch 6: 2.0s to complete
#     error(train)=1.06e+00, acc(train)=6.93e-01, error(valid)=1.07e+00, acc(valid)=6.89e-01
# ...
# Epoch 7: 2.0s to complete
#     error(train)=1.00e+00, acc(train)=7.10e-01, error(valid)=1.01e+00, acc(valid)=7.05e-01
# ...
# Epoch 8: 2.1s to complete
#     error(train)=9.47e-01, acc(train)=7.22e-01, error(valid)=9.58e-01, acc(valid)=7.23e-01
# ...
# Epoch 9: 2.3s to complete
# ...

# %%
weight_decay
# Out:
# 3.162277660168379e-06

# %%
# Plot the validation accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['AdamW', 'AdamW+cosine']
for stats, k in zip(list(sche_stats.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, 2], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the validation accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['AdamW', 'AdamW+cosine']
for stats, k in zip(list(sche_stats.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, -1], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Accuracy')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
test_data = EMNISTDataProvider('test', batch_size=15800, rng=rng)
test_accs = []
m = list(sche_models.values())
adamW_acc = evaluation_acc(test_data, m[0])
test_accs.append(adamW_acc)
adamW_cos_acc = evaluation_acc(test_data, m[1])
test_accs.append(adamW_cos_acc)
test_accs
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f5ce1103550>)
# [0.824873417721519, 0.8331645569620253]

# %%
num_epochs = 100
weight_decay = 0.0001 * ((batch_size * 1.0 / (train_data.num_batches * num_epochs)) ** 0.5)
sches = [
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.00005, 
                                    max_learning_rate=0.00015,
                                    total_iters_per_period=100.,
                                    max_learning_rate_discount_factor=0.8,
                                    period_iteration_expansion_factor=1.0),
    CosineAnnealingWithWarmRestarts(min_learning_rate=0.00005, 
                                    max_learning_rate=0.00015,
                                    total_iters_per_period=25.,
                                    max_learning_rate_discount_factor=0.9,
                                    period_iteration_expansion_factor=2)]

models_4_3 = OrderedDict()
stats_4_3 = OrderedDict()
final_train_errors = []
final_valid_errors = []
final_train_accs = []
final_valid_accs = []


for sche in sches:
    layers = [AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
              ReluLayer(),
              AffineLayer(hidden_dim, output_dim, weights_init, biases_init)]

    model = MultipleLayerModel(layers)
    learning_rule = AdamLearningRuleWithWeightDecay(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, weight_decay=weight_decay)

    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2, optimiser = train_model_and_plot_stats(
            model, error, learning_rule, train_data, valid_data, num_epochs, sche, stats_interval, notebook=True)
    plt.show()
    
    models_4_3[sche] = model
    stats_4_3[sche] = stats
    final_train_errors.append(stats[-1, 0])
    final_valid_errors.append(stats[-1, 2])
    final_train_accs.append(stats[-1, 1])
    final_valid_accs.append(stats[-1, -1])
    
    print('    final error(train) = {0:.2e}'.format(stats[-1, 0]))
    print('    final error(valid) = {0:.2e}'.format(stats[-1, 2]))
    print('    final acc(train)   = {0:.2e}'.format(stats[-1, 1]))
    print('    final acc(valid)   = {0:.2e}'.format(stats[-1, -1]))
    print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))
# Out:
# ...
# Epoch 1: 2.1s to complete
#     error(train)=1.60e+00, acc(train)=5.54e-01, error(valid)=1.60e+00, acc(valid)=5.51e-01
# ...
# Epoch 2: 2.1s to complete
#     error(train)=1.31e+00, acc(train)=6.31e-01, error(valid)=1.32e+00, acc(valid)=6.24e-01
# ...
# Epoch 3: 1.9s to complete
#     error(train)=1.15e+00, acc(train)=6.71e-01, error(valid)=1.16e+00, acc(valid)=6.67e-01
# ...
# Epoch 4: 2.0s to complete
#     error(train)=1.05e+00, acc(train)=6.95e-01, error(valid)=1.06e+00, acc(valid)=6.91e-01
# ...
# Epoch 5: 2.1s to complete
#     error(train)=9.61e-01, acc(train)=7.19e-01, error(valid)=9.74e-01, acc(valid)=7.15e-01
# ...
# Epoch 6: 2.0s to complete
#     error(train)=8.95e-01, acc(train)=7.35e-01, error(valid)=9.09e-01, acc(valid)=7.32e-01
# ...
# Epoch 7: 2.0s to complete
#     error(train)=8.37e-01, acc(train)=7.51e-01, error(valid)=8.51e-01, acc(valid)=7.45e-01
# ...
# Epoch 8: 2.2s to complete
#     error(train)=7.95e-01, acc(train)=7.59e-01, error(valid)=8.08e-01, acc(valid)=7.56e-01
# ...
# Epoch 9: 2.2s to complete
# ...

# %%
# Plot the validation accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['AdamW+cosine', 'AdamW+cosine+restarts']
for stats, k in zip(list(stats_4_3.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, -2], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Error')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()

# %%
# Plot the validation accuracy
plt.close()
plt.figure(figsize=(8,8))
labels = ['AdamW+cosine', 'AdamW+cosine+restarts']
for stats, k in zip(list(stats_4_3.values()), labels):
    plt.plot(np.arange(1, stats.shape[0]) * stats_interval, stats[1:, -1], label=k, linewidth=2)
plt.legend(loc=0)
plt.ylabel('Error')
plt.xlabel('Epoch Number')
plt.title('Validation Accuracy')
# plt.savefig('./plots/4_3_sgd_lr.png', dpi=1000)
#plt.savefig('./plots/4_3_sgd_lr.eps', format='eps', dpi=1000)
plt.show()
